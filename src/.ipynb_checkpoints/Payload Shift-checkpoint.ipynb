# %% [markdown]
# # Payload Shift
#
# How robust are these models to payload weight changes mid-flight?

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm

from utilities import get_agent
from environments import OctorotorEnvSelector
from systems.pid_agent import PIDAgent
from multirotor.helpers import DataLog

# %%
def get_tte(initial_pos: tuple, waypoints: np.ndarray, x: np.ndarray, y:np.ndarray, z:np.ndarray) -> np.ndarray:
        """
        Calculates the trajectory tracking error. 
        The distance between the current point and the vector between previous and next wp. Uses ||v1 x v2|| / ||v1||.

        Parameters
        ----------
        initial_pos : tuple  
            the initial position of the UAV.
        waypoints : np.ndarray 
            the reference positions at each point in time.
        x : np.ndarray 
            the x positions of the UAV.
        y : np.ndarray 
            the y positions of the UAV.
        z : np.ndarray
            the z positions of the UAV.

        Returns
        -------
        np.ndarray 
            the trajectory tracking error at each point in time.
        """
        ttes = []
        prev = initial_pos
        for i, waypoint in enumerate(waypoints):
            if i > 0 and not np.array_equal(waypoints[i-1], waypoints[i]):
                prev = waypoints[i-1]

            v1 = waypoint - prev
            v2 = np.array([x[i],y[i],z[i]]) - prev
            tte = np.linalg.norm(np.cross(v1, v2)) / (np.linalg.norm(v1) + 1e-6)
            ttes.append(tte)
                
        return np.array(ttes)

def toc(tte: np.ndarray):
    corridor = 5
    return len(tte[tte > corridor]) / 2

def completed_mission(waypoints: np.ndarray, x: np.ndarray, y: np.ndarray, z: np.ndarray, radius: float = 0.65):
        for waypoint in waypoints:
            reached_waypoint = False

            for position in zip(x,y,z):
                dist = np.linalg.norm(waypoint - position)

                if dist <= radius:
                    reached_waypoint = True
                    break

            if not reached_waypoint:
                return False
            
        return True

# %%
env_selector = OctorotorEnvSelector()
pid_sl_params = {'steps_u':50, 'scaling_factor':0, 'window_distance':10}
pid_sl_agent = PIDAgent()

pid_params = {'steps_u':50, 'scaling_factor':0, 'window_distance':1000}
pid_agent = PIDAgent()

study, naive_agent, naive_params = get_agent('naive')
naive_params['steps_u'] = 50
naive_params['bounding_rect_length']=1000

study, oracle_agent, oracle_params = get_agent('oracle')
oracle_params['steps_u'] = 50
oracle_params['bounding_rect_length']=1000

study, lstm_agent, lstm_params = get_agent('windlstm')
lstm_params['steps_u'] = 50
lstm_params['bounding_rect_length']=1000
# Out:
# [I 2023-09-29 00:39:46,561] Using an existing study with name 'naive' instead of creating a new one.
# [I 2023-09-29 00:39:48,105] Using an existing study with name 'oracle' instead of creating a new one.
# [I 2023-09-29 00:39:48,151] Using an existing study with name 'windlstm' instead of creating a new one.

# %%
all_agents = [pid_agent, pid_sl_agent, naive_agent, oracle_agent, lstm_agent]
all_params = [pid_params, pid_sl_params, naive_params, oracle_params, lstm_params]
names = ['PID', 'PID SL', 'Naive Agent', 'Oracle Agent', 'LSTM Agent']
env_types = ['sliding', 'sliding', 'naive', 'oracle', 'lstm']

# %%
nasa_wp = np.asarray([ # defines a real trajectory shown in a NASA paper
    [164.0146725649829, -0.019177722744643688, 30],
    [165.6418055187678, 111.5351051245816, 30],
    [127.3337449710234, 165.73576059611514, 30],
    [-187.28170707810204, 170.33217775914818, 40],
    [-192.03130502498243, 106.30660058604553, 40],
    [115.89920266153058, 100.8644210617058, 30],
    [114.81859536317643, 26.80923518165946, 30],
    [-21.459931490011513, 32.60508110653609, 30]
])

# %%
def sample_wind_range(magnitude):
    random_angle_degrees = np.random.uniform(0, 360)

    # Step 2: Convert the angle to radians
    random_angle_radians = np.deg2rad(random_angle_degrees)
    
    # Step 3: Calculate the components of the unit vector
    x_component = np.cos(random_angle_radians)
    y_component = np.sin(random_angle_radians)
    
    # Step 4: Create the unit vector
    unit_vector = np.array([x_component, y_component]) 
    wind_vector = unit_vector * magnitude

    wind_range = [(wind_vector[0], wind_vector[0]), (wind_vector[1], wind_vector[1]), (0,0)]
    return wind_range, wind_vector

# %%
def run_trajectory(env_selector, agent, params, current_mass, env_type, new_uav=False):
    wind_ranges, wind_vector = sample_wind_range(np.random.uniform(0,10))
    env = env_selector.get_env(env_type, params, wind_ranges, nasa_wp, start_alt=30, has_turbulence=True)

    done = False
    state = np.array(env.reset(), dtype=np.float32)
    log = DataLog(env.base_env.vehicle, env.base_env.ctrl,
                      other_vars=('reward',))

    seconds = 0
    while not done:
        action = agent.predict(state, deterministic=True)[0]
        state, reward, done, info = env.step(action)
        state = np.array(state, dtype=np.float32)
        log.log(reward=reward)
        seconds += 0.5

        if seconds == 20:
            env.base_env.vehicle.params.mass = current_mass

    log.done_logging()
    return log, info

# %%
def run_masses(env_selector, agents, params, masses, n_rep, types, names):
    results = pd.DataFrame(columns=['Agent', 'Mass', 'Total TTE', 'Mean TTE', 'Completed Mission', 'Reward', 'Time Outside Corridor'])
    for i in tqdm(range(n_rep)):
        for mass in masses:
            for agent, name, param, env_type in zip(agents, names, params, types):
                log, info = run_trajectory(env_selector, agent, param, mass, env_type)
                traj_err = get_tte(np.array([0,0,0]), log.target.position, log.x, log.y, log.z)
                new_result = {
                    'Agent': name,
                    'Mass': mass,
                    'Mean TTE': np.mean(traj_err),
                    'Total TTE': np.sum(traj_err),
                    'Completed Mission': completed_mission(nasa_wp, log.x, log.y, log.z, radius=5),
                    'Reward': np.sum(log.reward),
                    'Time Outside Corridor': toc(traj_err)
                }
                results = pd.concat([results, pd.DataFrame([new_result])], ignore_index=True)

    return results

# %%
masses = [8, 12]
n_rep = 5
results = run_masses(env_selector, all_agents, all_params, masses, n_rep, env_types, names)
# Out:
#   0%|                                                                                                                                                                                         | 0/5 [00:00<?, ?it/s]/home/courseac/miniconda3/envs/supervisor-control/lib/python3.9/site-packages/torch/nn/modules/rnn.py:769: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484775609/work/aten/src/ATen/native/cudnn/RNN.cpp:968.)
#   result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [18:52<00:00, 226.59s/it]

# %%
results.to_csv('./data/payload_shift.csv')

# %%
results
# Out:
#            Agent Changes    Total TTE   Mean TTE Completed Mission  \
# 0            PID     NaN  2092.016748   9.730310              True
# 1         PID SL     NaN  2453.802114   3.456059              True
# 2    Naive Agent     NaN   868.424652   1.481953              True
# 3   Oracle Agent     NaN   537.229838   0.909018              True
# 4     LSTM Agent     NaN   503.325988   0.958716              True
# 5            PID     NaN  3523.144147  14.498536              True
# 6         PID SL     NaN  1002.757182   1.322899              True
# 7    Naive Agent     NaN  1163.727445   1.923516              True
# 8   Oracle Agent     NaN   557.172693   0.942763              True
# 9     LSTM Agent     NaN  1041.203302   1.971976              True
# 10           PID     NaN  2698.258274  12.434370              True
# 11        PID SL     NaN   830.974234   1.727597             False
# 12   Naive Agent     NaN   529.659307   0.924362              True
# 13  Oracle Agent     NaN   534.984014   0.900646              True
# 14    LSTM Agent     NaN   590.620680   1.131457              True
# 15           PID     NaN  4047.157073  16.060147              True
# 16        PID SL     NaN   182.554282   0.277438              True
# 17   Naive Agent     NaN   591.811458   1.031030              True
# 18  Oracle Agent     NaN   472.782848   0.802687              True
# 19    LSTM Agent     NaN   417.983889   0.805364              True
# 20           PID     NaN  1711.886038   7.962261              True
# 21        PID SL     NaN   421.219784   0.638212              True
# 22   Naive Agent     NaN   714.159589   1.231310              True
# 23  Oracle Agent     NaN  1262.303715   2.055869              True
# 24    LSTM Agent     NaN   404.561136   0.781006              True
# 25           PID     NaN  1899.201980   8.874776              True
# 26        PID SL     NaN   174.577852   0.265316              True
# 27   Naive Agent     NaN  1678.682520   2.830831              True
# 28  Oracle Agent     NaN   499.432187   0.835171              True
# 29    LSTM Agent     NaN   765.140478   1.422194              True
# 30           PID     NaN  2376.016556  10.285786              True
# 31        PID SL     NaN  1747.696133   2.547662              True
# 32   Naive Agent     NaN   758.617497   1.270716              True
# 33  Oracle Agent     NaN   501.342230   0.848295              True
# 34    LSTM Agent     NaN   425.477045   0.824568              True
# 35           PID     NaN  1972.474412   8.651204              True
# 36        PID SL     NaN   202.826480   0.307313              True
# 37   Naive Agent     NaN   633.701331   1.105936              True
# 38  Oracle Agent     NaN   510.050026   0.861571              True
# 39    LSTM Agent     NaN   413.829490   0.798899              True
# 40           PID     NaN  1864.906409   8.673983              True
# 41        PID SL     NaN   354.456625   0.537055              True
# 42   Naive Agent     NaN   499.732845   0.872134              True
# 43  Oracle Agent     NaN  1262.089307   2.082656              True
# 44    LSTM Agent     NaN   941.655495   1.776708              True
# 45           PID     NaN  1824.488359   8.565673              True
# 46        PID SL     NaN   502.753881   0.741525              True
# 47   Naive Agent     NaN   851.330918   1.445384              True
# 48  Oracle Agent     NaN   608.559573   1.029712              True
# 49    LSTM Agent     NaN  1101.051039   2.089281              True
#
#           Reward  Time Outside Corridor  Mass
# 0    3941.417236                   69.0   8.0
# 1   -4333.032227                    5.5   8.0
# 2   11400.787109                    0.5   8.0
# 3   14627.111328                    0.5   8.0
# 4   14999.362305                    0.5   8.0
# 5  -11348.631836                   78.5  12.0
# 6   10071.567383                    4.5  12.0
# 7    8503.278320                   19.5  12.0
# 8   14421.203125                    0.5  12.0
# 9    9655.013672                    0.5  12.0
# 10  -2284.161133                   76.5   8.0
# 11  -5640.419922                    0.5   8.0
# 12  14726.777344                    0.5   8.0
# 13  14647.218750                    0.5   8.0
# 14  14095.640625                    0.5   8.0
# 15 -16574.921875                   86.0  12.0
# 16  18133.425781                    0.5  12.0
# 17  14117.604492                    0.5  12.0
# 18  15265.041992                    0.5  12.0
# 19  15824.817383                    0.5  12.0
# 20   7717.192383                   70.0   8.0
# 21  15764.796875                    0.5   8.0
# 22  12903.364258                    0.5   8.0
# 23   7466.711914                    0.5   8.0
# 24  15937.380859                    0.5   8.0
# 25   5931.962891                   68.5  12.0
# 26  18205.947266                    0.5  12.0
# 27   3308.942871                   12.5  12.0
# 28  15002.624023                    0.5  12.0
# 29  12420.013672                    0.5  12.0
# 30   1679.656494                   71.0   8.0
# 31   2615.427002                    0.5   8.0
# 32  12495.931641                    8.0   8.0
# 33  14977.791016                    0.5   8.0
# 34  15731.094727                    0.5   8.0
# 35   4852.916016                   64.5  12.0
# 36  17929.339844                    0.5  12.0
# 37  13694.584961                    0.5  12.0
# 38  14908.702148                    0.5  12.0
# 39  15860.275391                    0.5  12.0
# 40   6368.814453                   67.5   8.0
# 41  16443.171875                    0.5   8.0
# 42  15016.779297                    0.5   8.0
# 43   7438.559570                    0.5   8.0
# 44  10645.757812                    7.0   8.0
# 45   6602.443359                   66.5  12.0
# 46  15013.671875                    0.5  12.0
# 47  11548.933594                    0.5  12.0
# 48  13929.571289                    0.5  12.0
# 49   9076.101562                    0.5  12.0

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
sns.boxplot(x='Agent', y='Mean TTE', data=results, hue='Mass')
plt.title('Mean TTE by Agent')
plt.ylabel('Mean TTE')
plt.xlabel('Agent')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

plt.tight_layout()  # Ensure labels are not cut off
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
sns.boxplot(x='Agent', y='Time Outside Corridor', data=results[results['Agent'] != 'PID'])
plt.title('Mean TTE by Agent')
plt.ylabel('Mean TTE')
plt.xlabel('Agent')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

plt.tight_layout()  # Ensure labels are not cut off
plt.show()

# %% [markdown]
# Sweep over a bunch of masses with our proposed agent

# %%
masses = [4, 6, 8, 10, 12, 14, 16, 18]
n_rep = 10
results_masses = run_masses(env_selector, [lstm_agent], [lstm_params], masses, n_rep, ['lstm'], ['LSTM Agent'])
# Out:
#   0%|                                                                                    | 0/10 [00:00<?, ?it/s]/home/courseac/miniconda3/envs/supervisor-control/lib/python3.9/site-packages/torch/nn/modules/rnn.py:769: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484775609/work/aten/src/ATen/native/cudnn/RNN.cpp:968.)
#   result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# /home/courseac/miniconda3/envs/supervisor-control/lib/python3.9/site-packages/torch/nn/modules/rnn.py:769: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484775609/work/aten/src/ATen/native/cudnn/RNN.cpp:968.)
#   result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# 100%|██████████████████████████████████████████████████████████████████████████| 10/10 [24:13<00:00, 145.35s/it]

# %%
results_masses.to_csv('./data/lstm_mass_sweep.csv')

# %%
results_masses = pd.read_csv('./data/lstm_mass_sweep.csv')

# %%
import seaborn as sns

# combine this with the one for the other UAV type too
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
sns.boxplot(x='Mass', y='Mean TTE', color='green', data=results_masses, showfliers=False)
plt.title('Mean TTE Under Suddent Mass Shift and Wind')
plt.ylabel('Mean TTE')
plt.xlabel('Sudden Mass Shift (kg)')

plt.tight_layout()  # Ensure labels are not cut off
plt.show()

# %%
masses = [8, 10, 12, 14, 16, 18]
n_rep = 10
results_masses_new = run_masses(env_selector, [lstm_agent], [lstm_params], masses, n_rep, ['dji_lstm'], ['LSTM Agent'], new_uav=True)
# Out:
#   0%|                                                                                    | 0/10 [00:00<?, ?it/s]/home/courseac/miniconda3/envs/supervisor-control/lib/python3.9/site-packages/torch/nn/modules/rnn.py:769: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484775609/work/aten/src/ATen/native/cudnn/RNN.cpp:968.)
#   result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#   0%|                                                                                    | 0/10 [00:34<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 masses = [4, 6, 8, 10, 12, 14, 16, 18]
#       2 n_rep = 10
# ----> 3 results_masses_new = run_masses(env_selector, [lstm_agent], [lstm_params], masses, n_rep, ['lstm'], ['LSTM Agent'], new_uav=True)
#
# Cell In[8], line 6, in run_masses(env_selector, agents, params, masses, n_rep, types, names, new_uav)
#       4 for mass in masses:
#       5     for agent, name, param, env_type in zip(agents, names, params, types):
# ----> 6         log, info = run_trajectory(env_selector, agent, param, mass, env_type, new_uav)
#       7         traj_err = get_tte(np.array([0,0,0]), log.target.position, log.x, log.y, log.z)
#       8         new_result = {
#       9             'Agent': name,
#      10             'Mass': mass,
#    (...)
#      15             'Time Outside Corridor': toc(traj_err)
#      16         }
#
# Cell In[7], line 15, in run_trajectory(env_selector, agent, params, current_mass, env_type, new_uav)
#      13 while not done:
#      14     action = agent.predict(state, deterministic=True)[0]
# ---> 15     state, reward, done, info = env.step(action)
#      16     state = np.array(state, dtype=np.float32)
#      17     log.log(reward=reward)
#
# File ~/projects/wind-estimation/src/systems/long_multirotor_wind_estimation.py:77, in LongTrajEnv.step(self, u)
#      75 done = False
#      76 reward = 0
# ---> 77 s, reward, _, info = self.base_env.step(u)
#      79 # if the sub gym env has reached its waypoint at the end of the bounding rectangle
#      80 if info.get('reached'):
#      81     # reward it if it was one of the original waypoints
#
# File ~/projects/wind-estimation/src/systems/multirotor_wind_estimation.py:394, in MultirotorTrajEnv.step(self, u, **kwargs)
#     390 # print("sc", prev_scalar_factor)
#     391
#     392 # Calculate the intersection point coordinates
#     393 prev_intersection_point = self.prev_waypt + prev_scalar_factor * self._des_unit_vec
# --> 394 x, r, d, *_, i = super().step(np.concatenate(([self.calculate_safe_sliding_bound(self.next_waypt, prev_intersection_point, distance=self.window_distance),u])))
#     396 dist = np.linalg.norm(self.next_waypt - self.x[:3])
#     397 reached = dist <= self._proximity
#
# File ~/projects/wind-estimation/src/systems/base.py:69, in SystemEnv.step(self, u, from_x, persist, dt, is_velocity)
#      67 old_dxdt = self.dxdt
#      68 old_x = np.asarray(self.x if from_x is None else from_x, dtype=self.dtype)
# ---> 69 new_dxdt = np.asarray(self.dynamics(self.t, old_x, u), dtype=self.dtype)
#      70 dt = self.dt if dt is None else dt
#      71 new_x = (old_x + 0.5 * (old_dxdt + new_dxdt) * dt).astype(self.dtype)
#
# File ~/miniconda3/envs/supervisor-control/lib/python3.9/site-packages/control/iosys.py:414, in InputOutputSystem.dynamics(self, t, x, u, params)
#     380 """Compute the dynamics of a differential or difference equation.
#     381
#     382 Given time `t`, input `u` and state `x`, returns the value of the
#    (...)
#     411 dx/dt or x[t+dt] : ndarray
#     412 """
#     413 self._update_params(params)
# --> 414 return self._rhs(t, x, u)
#
# File ~/miniconda3/envs/supervisor-control/lib/python3.9/site-packages/control/iosys.py:865, in NonlinearIOSystem._rhs(self, t, x, u)
#     864 def _rhs(self, t, x, u):
# --> 865     xdot = self.updfcn(t, x, u, self._current_params) \
#     866         if self.updfcn is not None else []
#     867     return np.array(xdot).reshape((-1,))
#
# File ~/projects/wind-estimation/src/systems/multirotor_wind_estimation.py:170, in create_multirotor.<locals>.update_fn(t, x, u, params)
#     169 def update_fn(t, x, u, params):
# --> 170     dynamics = ctrl.step(u, ref_is_error=False, is_velocity=True)
#     171     speeds = m.allocate_control(dynamics[0], dynamics[1:4]) # see if the inverse works with small eps
#     172     speeds *= fault_mult # maybe do tha in the alocate control function
#
# File ~/projects/supervisory-control/src/vendor/multirotor/multirotor/controller/pid.py:705, in Controller.step(self, reference, measurement, ref_is_error, feed_forward_velocity, persist, is_velocity)
#     703 if self.n % self.steps_a == 0:
#     704     dt = self.steps_a * self.vehicle.simulation.dt
# --> 705     self._pitch_roll = self.ctrl_v.step(self._ref_vel, self.vehicle.velocity[:2], dt=dt, persist=persist)
#     706     ref_orientation = np.clip(np.asarray([self._pitch_roll[1], self._pitch_roll[0], ref_yaw]), -0.3926991, 0.3926991) # added clipping here
#     707     ref_rate = self.ctrl_a.step(ref_orientation, self.vehicle.orientation, dt=dt)
#
# File ~/projects/supervisory-control/src/vendor/multirotor/multirotor/controller/pid.py:287, in VelController.step(self, reference, measurement, dt, persist)
#     285 def step(self, reference, measurement, dt, persist: bool=True):
#     286     # desired pitch, roll
# --> 287     pitch_roll = super().step(reference, measurement, dt=dt, persist=persist)
#     288     # ctrl[0] -> x dir -> pitch -> forward
#     289     # ctrl[1] -> y dir -> roll -> lateral
#     290     pitch_roll[0:2] = np.clip(pitch_roll[0:2], a_min=-self.max_tilt, a_max=self.max_tilt)
#
# File ~/projects/supervisory-control/src/vendor/multirotor/multirotor/controller/pid.py:155, in PIDController.step(self, reference, measurement, dt, ref_is_error, persist)
#     153     err = reference - measurement
#     154 err_p = self.k_p * err
# --> 155 err_i = self.k_i * np.clip(
#     156     self.err_i + trapezoid((self.err, err), dx=dt, axis=0),
#     157     a_min=-self.max_err_i, a_max=self.max_err_i
#     158 )
#     159 err_d = self.k_d * (err - self.err) / dt
#     160 action = err_p + err_i + err_d
#
# File <__array_function__ internals>:200, in clip(*args, **kwargs)
#
# File ~/miniconda3/envs/supervisor-control/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2111, in clip(a, a_min, a_max, out, **kwargs)
#    2107 def _clip_dispatcher(a, a_min, a_max, out=None, **kwargs):
#    2108     return (a, a_min, a_max)
# -> 2111 @array_function_dispatch(_clip_dispatcher)
#    2112 def clip(a, a_min, a_max, out=None, **kwargs):
#    2113     """
#    2114     Clip (limit) the values in an array.
#    2115
#    (...)
#    2178
#    2179     """
#    2180     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#
# KeyboardInterrupt:

# %%
results_masses_new.to_csv('./data/lstm_mass_sweep_new.csv')

# %%
results_masses_new = pd.read_csv('./data/lstm_mass_sweep_new.csv')

# %%
results_masses_new

# %%
results_masses_new['Agent'] = 'DJI'

# %%
results_masses['Agent'] = 'Tarot'

# %%
results = pd.concat([results_masses, results_masses_new])
results

# %%
import seaborn as sns

# combine this with the one for the other UAV type too
plt.figure(figsize=(8, 4))  # Adjust the figure size if needed
ax = sns.boxplot(x='Mass', y='Mean TTE', hue='Agent', data=results, showfliers=True, palette="colorblind")
plt.title('Mean TTE Under Sudden Mass Shift and Wind')
plt.ylabel('Mean TTE')
plt.xlabel('Sudden Mass Shift (kg)')
ax.legend(title='Model')

plt.tight_layout()  # Ensure labels are not cut off
plt.show()
