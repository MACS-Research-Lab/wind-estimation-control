# %% [markdown]
# # Wind Impact on Blending Agent Performance
#
# How robust is the RL architecture trained on to blend other RL policies to all wind?

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm

from utilities import get_agent
from environments import OctorotorEnvSelector
from systems.pid_agent import PIDAgent
from multirotor.helpers import DataLog

# %%
study, best_agent, best_params = get_agent('blending@softmax@scaled', filepath='BlendingEnv')

best_params['steps_u']=50
best_params['scaling_factor']=5
best_params['bounding_rect_length']=200
best_params['window_distance']=10
# Out:
# [I 2023-09-13 15:14:41,655] Using an existing study with name 'blending@softmax' instead of creating a new one.

# %%
env_selector = OctorotorEnvSelector()
square_wpts = np.array([[100,0,0], [100,100,0], [0,100,0], [0,0,0]])

# %%
def get_tte(initial_pos: tuple, waypoints: np.ndarray, x: np.ndarray, y:np.ndarray, z:np.ndarray) -> np.ndarray:
        """
        Calculates the trajectory tracking error. 
        The distance between the current point and the vector between previous and next wp. Uses ||v1 x v2|| / ||v1||.

        Parameters
        ----------
        initial_pos : tuple  
            the initial position of the UAV.
        waypoints : np.ndarray 
            the reference positions at each point in time.
        x : np.ndarray 
            the x positions of the UAV.
        y : np.ndarray 
            the y positions of the UAV.
        z : np.ndarray
            the z positions of the UAV.

        Returns
        -------
        np.ndarray 
            the trajectory tracking error at each point in time.
        """
        ttes = []
        prev = initial_pos
        for i, waypoint in enumerate(waypoints):
            if i > 0 and not np.array_equal(waypoints[i-1], waypoints[i]):
                prev = waypoints[i-1]

            v1 = waypoint - prev
            v2 = np.array([x[i],y[i],z[i]]) - prev
            tte = np.linalg.norm(np.cross(v1, v2)) / (np.linalg.norm(v1) + 1e-6)
            ttes.append(tte)
                
        return np.array(ttes)

# %%
def toc(tte: np.ndarray):
    corridor = 5
    return len(tte[tte > corridor]) / 2 # every half of a second we record data

# %%
def completed_mission(waypoints: np.ndarray, x: np.ndarray, y: np.ndarray, z: np.ndarray, radius: float = 0.65):
        for waypoint in waypoints:
            reached_waypoint = False

            for position in zip(x,y,z):
                dist = np.linalg.norm(waypoint - position)

                if dist <= radius:
                    reached_waypoint = True
                    break

            if not reached_waypoint:
                return False
            
        return True

# %%
def run_trajectory(env_selector, wind_ranges: np.ndarray, agent, params):
    env = env_selector.get_env("blending", params, wind_ranges, square_wpts)
    done = False
    state = np.array(env.reset(), dtype=np.float32)
    log = DataLog(env.base_env.vehicle, env.base_env.ctrl,
                      other_vars=('reward',))
    while not done:
        action = agent.predict(state, deterministic=True)[0]
        state, reward, done, info = env.step(action)
        state = np.array(state, dtype=np.float32)
        log.log(reward=reward)

    log.done_logging()
    return log, info

# %%
wind_range_dict = {
    'zero': [(0,0), (0,0), (0,0)],
    'n5': [(0,0), (5,5), (0,0)],
    'n7': [(0,0), (7,7), (0,0)],
    'n10': [(0,0), (10,10), (0,0)],
    's5': [(0,0), (-5,-5), (0,0)],
    's7': [(0,0), (-7,-7), (0,0)],
    's10': [(0,0), (-10,-10), (0,0)],
    'e5': [(5,5), (0,0), (0,0)],
    'e7': [(7,7), (0,0), (0,0)],
    'e10': [(10,10), (0,0), (0,0)],
    'w5': [(-5,-5), (0,0), (0,0)],
    'w7': [(-7,-7), (0,0), (0,0)],
    'w10': [(-10,-10), (0,0), (0,0)],
    'nw5': [(-3.53553391,-3.53553391), (3.53553391,3.53553391), (0,0)],
    'nw7': [(-4.94974747,-4.94974747), (4.94974747,4.94974747), (0,0)],
    'nw10': [(-7.07106781,-7.07106781), (7.07106781,7.07106781), (0,0)],
    'sw5': [(-3.53553391,-3.53553391), (-3.53553391,-3.53553391), (0,0)],
    'sw7': [(-4.94974747,-4.94974747), (-4.94974747,-4.94974747), (0,0)],
    'sw10': [(-7.07106781,-7.07106781), (-7.07106781,-7.07106781), (0,0)],
    'ne5': [(3.53553391,3.53553391), (3.53553391,3.53553391), (0,0)],
    'ne7': [(4.94974747,4.94974747), (4.94974747,4.94974747), (0,0)],
    'ne10': [(7.07106781,7.07106781), (7.07106781,7.07106781), (0,0)],
    'se5': [(3.53553391,3.53553391), (-3.53553391,-3.53553391), (0,0)],
    'se7': [(4.94974747,4.94974747), (-4.94974747,-4.94974747), (0,0)],
    'se10': [(7.07106781,7.07106781), (-7.07106781,-7.07106781), (0,0)],
}

# %%
wind_results = pd.DataFrame(columns=['Wind', 'Total TTE', 'Mean TTE', 'Completed Mission', 'Reward', 'Time Outside Corridor'])

# %%
def run_wind_sweep(results, wind_dict, agent, params):
    for wind in tqdm(wind_dict.keys()):
        log, info = run_trajectory(env_selector, wind_dict[wind], agent, params)
        traj_err = get_tte(np.array([0,0,0]), log.target.position, log.x, log.y, log.z)
        new_result = {
            'Wind': wind,
            'Mean TTE': np.mean(traj_err),
            'Total TTE': np.sum(traj_err),
            'Completed Mission': completed_mission(square_wpts, log.x, log.y, log.z, radius=5),
            'Reward': np.sum(log.reward),
            'Time Outside Corridor': toc(traj_err)
        }
        results = pd.concat([results, pd.DataFrame([new_result])], ignore_index=True)

    return results

# %%
wind_results = run_wind_sweep(wind_results, wind_range_dict, best_agent, best_params)
# Out:
#   0%|                                                                                                                                                                                        | 0/25 [00:00<?, ?it/s][I 2023-09-13 15:14:43,276] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:14:43,335] Using an existing study with name 'midwind' instead of creating a new one.
#   4%|███████                                                                                                                                                                         | 1/25 [00:07<03:07,  7.83s/it][I 2023-09-13 15:14:51,102] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:14:51,156] Using an existing study with name 'midwind' instead of creating a new one.
#   8%|██████████████                                                                                                                                                                  | 2/25 [00:12<02:20,  6.10s/it][I 2023-09-13 15:14:55,988] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:14:56,058] Using an existing study with name 'midwind' instead of creating a new one.
#  12%|█████████████████████                                                                                                                                                           | 3/25 [00:17<02:02,  5.57s/it][I 2023-09-13 15:15:00,928] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:15:00,979] Using an existing study with name 'midwind' instead of creating a new one.
#  16%|████████████████████████████▏                                                                                                                                                   | 4/25 [00:23<01:58,  5.63s/it][I 2023-09-13 15:15:06,654] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:15:06,726] Using an existing study with name 'midwind' instead of creating a new one.
#  20%|███████████████████████████████████▏                                                                                                                                            | 5/25 [00:28<01:47,  5.37s/it][I 2023-09-13 15:15:11,562] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:15:11,613] Using an existing study with name 'midwind' instead of creating a new one.
#  24%|██████████████████████████████████████████▏                                                                                                                                     | 6/25 [00:33<01:40,  5.31s/it][I 2023-09-13 15:15:16,761] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:15:16,814] Using an existing study with name 'midwind' instead of creating a new one.
#  28%|█████████████████████████████████████████████████▎                                                                                                                              | 7/25 [00:39<01:37,  5.43s/it][I 2023-09-13 15:15:22,445] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:15:22,498] Using an existing study with name 'midwind' instead of creating a new one.
#  32%|████████████████████████████████████████████████████████▎                                                                                                                       | 8/25 [00:44<01:29,  5.26s/it][I 2023-09-13 15:15:27,346] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:15:27,398] Using an existing study with name 'midwind' instead of creating a new one.
#  36%|███████████████████████████████████████████████████████████████▎                                                                                                                | 9/25 [00:49<01:22,  5.17s/it][I 2023-09-13 15:15:32,313] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:15:32,367] Using an existing study with name 'midwind' instead of creating a new one.
#  40%|██████████████████████████████████████████████████████████████████████                                                                                                         | 10/25 [00:54<01:20,  5.40s/it][I 2023-09-13 15:15:38,223] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:15:38,276] Using an existing study with name 'midwind' instead of creating a new one.
#  44%|█████████████████████████████████████████████████████████████████████████████                                                                                                  | 11/25 [00:59<01:13,  5.24s/it][I 2023-09-13 15:15:43,092] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:15:43,145] Using an existing study with name 'midwind' instead of creating a new one.
#  48%|████████████████████████████████████████████████████████████████████████████████████                                                                                           | 12/25 [01:04<01:07,  5.16s/it][I 2023-09-13 15:15:48,092] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:15:48,144] Using an existing study with name 'midwind' instead of creating a new one.
#  52%|███████████████████████████████████████████████████████████████████████████████████████████                                                                                    | 13/25 [01:11<01:06,  5.53s/it][I 2023-09-13 15:15:54,462] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:15:54,515] Using an existing study with name 'midwind' instead of creating a new one.
#  56%|██████████████████████████████████████████████████████████████████████████████████████████████████                                                                             | 14/25 [01:16<00:58,  5.33s/it][I 2023-09-13 15:15:59,333] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:15:59,388] Using an existing study with name 'midwind' instead of creating a new one.
#  60%|█████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                      | 15/25 [01:20<00:52,  5.20s/it][I 2023-09-13 15:16:04,233] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:16:04,284] Using an existing study with name 'midwind' instead of creating a new one.
#  64%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                               | 16/25 [01:26<00:46,  5.16s/it][I 2023-09-13 15:16:09,298] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:16:09,375] Using an existing study with name 'midwind' instead of creating a new one.
#  68%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                        | 17/25 [01:30<00:40,  5.09s/it][I 2023-09-13 15:16:14,217] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:16:14,270] Using an existing study with name 'midwind' instead of creating a new one.
#  72%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                 | 18/25 [01:35<00:35,  5.05s/it][I 2023-09-13 15:16:19,164] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:16:19,245] Using an existing study with name 'midwind' instead of creating a new one.
#  76%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                          | 19/25 [01:41<00:30,  5.09s/it][I 2023-09-13 15:16:24,363] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:16:24,417] Using an existing study with name 'midwind' instead of creating a new one.
#  80%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                   | 20/25 [01:45<00:25,  5.01s/it][I 2023-09-13 15:16:29,194] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:16:29,323] Using an existing study with name 'midwind' instead of creating a new one.
#  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                            | 21/25 [01:51<00:20,  5.06s/it][I 2023-09-13 15:16:34,363] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:16:34,416] Using an existing study with name 'midwind' instead of creating a new one.
#  88%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                     | 22/25 [01:56<00:15,  5.05s/it][I 2023-09-13 15:16:39,401] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:16:39,455] Using an existing study with name 'midwind' instead of creating a new one.
#  92%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████              | 23/25 [02:01<00:10,  5.00s/it][I 2023-09-13 15:16:44,279] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:16:44,332] Using an existing study with name 'midwind' instead of creating a new one.
#  96%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████       | 24/25 [02:05<00:04,  4.97s/it][I 2023-09-13 15:16:49,180] Using an existing study with name 'highwind' instead of creating a new one.
# [I 2023-09-13 15:16:49,255] Using an existing study with name 'midwind' instead of creating a new one.
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 25/25 [02:11<00:00,  5.24s/it]

# %%
wind_results.to_csv('./data/blending_wind.csv')

# %%
wind_results = pd.read_csv('./data/blending_wind.csv') # or read cardinal_wind.csv for the Cardinal High agent

# %%
wind_results
# Out:
#     Unnamed: 0  Wind    Total TTE   Mean TTE  Completed Mission      Reward  \
# 0            0  zero   127.203993   0.614512               True   8673.1780
# 1            1    n5   148.179745   0.715844               True   8470.5800
# 2            2    n7   237.227029   1.135058               True   7603.6455
# 3            3   n10  2386.121091   9.819428               True -13820.0580
# 4            4    s5   206.234185   0.991511               True   7892.4510
# 5            5    s7   302.528117   1.420320               True   6955.5796
# 6            6   s10   761.437553   3.146436               True   2434.9097
# 7            7    e5   141.025523   0.681283               True   8536.9590
# 8            8    e7   234.320381   1.110523               True   7632.2397
# 9            9   e10  2497.242014  10.029084               True -14943.1570
# 10          10    w5   208.497997   1.007237               True   7878.8740
# 11          11    w7   310.142321   1.456067               True   6894.8500
# 12          12   w10  2948.486278  10.840023               True -19420.6050
# 13          13   nw5   152.062939   0.734604               True   8433.9290
# 14          14   nw7   221.051812   1.062749               True   7756.4863
# 15          15  nw10   431.566834   1.997995               True   5706.9110
# 16          16   sw5   202.719514   0.974613               True   7936.8677
# 17          17   sw7   294.916731   1.397710               True   7043.4014
# 18          18  sw10   535.010485   2.431866               True   4684.0674
# 19          19   ne5   103.101576   0.500493               True   8908.8990
# 20          20   ne7   166.052669   0.794510               True   8306.7930
# 21          21  ne10   379.872322   1.775104               True   6200.7110
# 22          22   se5   141.903256   0.685523               True   8522.8610
# 23          23   se7   212.087994   1.019654               True   7838.8555
# 24          24  se10   428.900526   1.976500               True   5720.6963
#
#     Time Outside Corridor
# 0                     0.0
# 1                     0.0
# 2                     0.0
# 3                    46.0
# 4                     0.0
# 5                     0.0
# 6                    18.0
# 7                     0.0
# 8                     0.0
# 9                    35.0
# 10                    0.0
# 11                    0.0
# 12                   41.5
# 13                    0.0
# 14                    0.0
# 15                    0.0
# 16                    0.0
# 17                    0.0
# 18                    0.0
# 19                    0.0
# 20                    0.0
# 21                    0.0
# 22                    0.0
# 23                    0.0
# 24                    0.0

# %%
print("Mean reward for 5 m/s: ", wind_results[wind_results['Wind'].str.contains("5")]['Reward'].mean())
print("Std reward for 5 m/s: ",wind_results[wind_results['Wind'].str.contains("5")]['Reward'].std())
print("Mean reward for 7 m/s: ", wind_results[wind_results['Wind'].str.contains("7")]['Reward'].mean())
print("Std reward for 7 m/s: ",wind_results[wind_results['Wind'].str.contains("7")]['Reward'].std())
print("Mean reward for 10 m/s: ", wind_results[wind_results['Wind'].str.contains("10")]['Reward'].mean())
print("Std reward for 10 m/s: ",wind_results[wind_results['Wind'].str.contains("10")]['Reward'].std())
# Out:
# Mean reward for 5 m/s:  8322.6775875
# Std reward for 5 m/s:  376.9811055185144
# Mean reward for 7 m/s:  7503.981374999999
# Std reward for 7 m/s:  497.23643555818643
# Mean reward for 10 m/s:  -2929.5655750000005
# Std reward for 10 m/s:  11047.988155764637
